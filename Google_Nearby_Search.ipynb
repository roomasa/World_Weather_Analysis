# %%
# Dependencies and Setup
import requests
import gmaps

# Import API key
from config import g_key

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwJ633wI62DDBujzVD36Za3QMCu-_PD4K9bdmbCswyy2HdfXK-BRBcreT_3RUuqadm46qxmZNWZKx70VfnrHET_QbvAnY2npk4fRU18SsiRssnVsukGvxVU4bT--bZoM0k8GinQmJYmGOtoRrRizAZY_8aN_qjMDdKRJMKqlv4LniDubAUSTKiPSZDoKicCSOB_TiqLMOpxZLyw68aSn-vz7EiPNHcLyhsQDztFM1kyuTCIDZ0CXqAPyQ9xCOocfy5d2CSqqGNwa3YZfEZxvdBpknWvO813rRET9gBuR5nkMs4ViOU0qS4nDCZBW2p3PUJBJ5uQ5-AQ7ow7L7sfLFLUduSFGbVVN9um2em-460JqI56wa6M4w9eh9ap_qbbb1G7j4xQCRdy3LbW9fDOcGbPjazWYGI_h_U4k7afjiomwFe8J_9N2LU0u',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594393802915,
#       'lng': 2.354352980291503},
#      'southwest': {'lat': 48.8567414197085, 'lng': 2.351655019708499}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Duo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
# ...

# %%
#Scroll through the information. Below the next_page_token is a results dictionary. To get all the hotels in the results dictionary we can get 
#the length of this dictionary by using, len(hotels["results"]).
len(hotels["results"])
# Out:
# 20

# %%
#to get the name of the first hotel in the list
hotels["results"][0]["name"]
# Out:
# 'Hôtel Duo'

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fb4b837962f0> in <module>
#       1 # Iterate through the DataFrame.
# ----> 2 for index, row in hotel_df.iterrows():
#       3     # Get the latitude and longitude.
#       4     lat = row["Lat"]
#       5     lng = row["Lng"]
#
# NameError: name 'hotel_df' is not defined
