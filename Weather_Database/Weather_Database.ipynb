# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# %%
#we'll pack the latitudes (lats) and longitudes (lngs) as pairs by zipping them (lat_lngs) with the zip() function
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#import citypy module
from citipy import citipy

# %%
# Import the requests library.
import requests

# %%
# Import the API key.
from config2 import weather_api_key

# %%
# bulilding the basic URL for the openweathermap with weather_api_key added to the url
#Starting URL for Weather Map API Call, saves the url as a variable.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ab24e37f7ae2440d7bfc6f65561985a9

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
#In the code block, we have initialized the counters at 1 because we want the first
#iteration of the logging for each recorded response and the set to start at 1.
# Loop through all the cities in our list.Let's use the enumerate() method to get the
#index of the city for logging purposes and the city for creating an endpoint URL.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        print(city_weather)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Date": city_date,
                         "Description": city_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# {'coord': {'lon': -134.9692, 'lat': -23.1203}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 78.22, 'feels_like': 77.18, 'temp_min': 78.22, 'temp_max': 78.22, 'pressure': 1012, 'humidity': 72, 'sea_level': 1012, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 14.05, 'deg': 94}, 'rain': {'1h': 0.14}, 'clouds': {'all': 11}, 'dt': 1612567580, 'sys': {'country': 'PF', 'sunrise': 1612536150, 'sunset': 1612583122}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# Processing Record 2 of Set 1 | horsham
# {'coord': {'lon': -0.3272, 'lat': 51.064}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 42.64, 'feels_like': 37.63, 'temp_min': 39.99, 'temp_max': 44.6, 'pressure': 1008, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 170}, 'clouds': {'all': 75}, 'dt': 1612567629, 'sys': {'type': 1, 'id': 1413, 'country': 'GB', 'sunrise': 1612510310, 'sunset': 1612544330}, 'timezone': 0, 'id': 2646557, 'name': 'Horsham', 'cod': 200}
# Processing Record 3 of Set 1 | longyearbyen
# {'coord': {'lon': 15.6401, 'lat': 78.2186}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 24.8, 'feels_like': 14.74, 'temp_min': 24.8, 'temp_max': 24.8, 'pressure': 1039, 'humidity': 86}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 310}, 'clouds': {'all': 75}, 'dt': 1612567513, 'sys': {'type': 1, 'id': 1663, 'country': 'SJ', 'sunrise': 0, 'sunset': 0}, 'timezone': 3600, 'id': 2729907, 'name': 'Longyearbyen', 'cod': 200}
# Processing Record 4 of Set 1 | flinders
# {'coord': {'lon': 150.8552, 'lat': -34.5833}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 70, 'feels_like': 71.24, 'temp_min': 70, 'temp_max': 70, 'pressure': 1003, 'humidity': 91}, 'visibility': 10000, 'wind': {'speed': 8.99, 'deg': 59, 'gust': 11.99}, 'rain': {'1h': 0.18}, 'clouds': {'all': 100}, 'dt': 1612567513, 'sys': {'type': 3, 'id': 20106, 'country': 'AU', 'sunrise': 1612552904, 'sunset': 1612601974}, 'timezone': 39600, 'id': 6255012, 'name': 'Flinders', 'cod': 200}
# Processing Record 5 of Set 1 | punta arenas
# {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 53.29, 'feels_like': 35.06, 'temp_min': 53.01, 'temp_max': 53.6, 'pressure': 1018, 'humidity': 47}, 'visibility': 10000, 'wind': {'speed': 26.46, 'deg': 270}, 'clouds': {'all': 0}, 'dt': 1612567629, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1612516964, 'sunset': 1612571561}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# Processing Record 6 of Set 1 | hilo
# {'coord': {'lon': -155.09, 'lat': 19.7297}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 72.27, 'feels_like': 67.71, 'temp_min': 66.99, 'temp_max': 78.8, 'pressure': 1010, 'humidity': 57}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 10}, 'rain': {'1h': 0.15}, 'clouds': {'all': 1}, 'dt': 1612566793, 'sys': {'type': 1, 'id': 7881, 'country': 'US', 'sunrise': 1612544035, 'sunset': 1612584895}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}
# Processing Record 7 of Set 1 | tecoanapa
# {'coord': {'lon': -98.75, 'lat': 16.5167}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 81.63, 'feels_like': 84.22, 'temp_min': 81.63, 'temp_max': 81.63, 'pressure': 1009, 'humidity': 65, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 7.81, 'deg': 219}, 'clouds': {'all': 24}, 'dt': 1612567630, 'sys': {'country': 'MX', 'sunrise': 1612530279, 'sunset': 1612571606}, 'timezone': -21600, 'id': 3516171, 'name': 'Barra de Tecoanapa', 'cod': 200}
# Processing Record 8 of Set 1 | qaanaaq
# {'coord': {'lon': -69.3632, 'lat': 77.484}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -6.68, 'feels_like': -18.09, 'temp_min': -6.68, 'temp_max': -6.68, 'pressure': 1031, 'humidity': 76, 'sea_level': 1031, 'grnd_level': 1026}, 'visibility': 10000, 'wind': {'speed': 8.37, 'deg': 60}, 'clouds': {'all': 100}, 'dt': 1612567373, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -14400, 'id': 3831208, 'name': 'Qaanaaq', 'cod': 200}
# Processing Record 9 of Set 1 | aklavik
# {'coord': {'lon': -135.0107, 'lat': 68.2191}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': -32.8, 'feels_like': -41.82, 'temp_min': -32.8, 'temp_max': -32.8, 'pressure': 1038, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 130}, 'clouds': {'all': 20}, 'dt': 1612567381, 'sys': {'type': 1, 'id': 821, 'country': 'CA', 'sunrise': 1612548048, 'sunset': 1612571243}, 'timezone': -25200, 'id': 5882953, 'name': 'Aklavik', 'cod': 200}
# Processing Record 10 of Set 1 | tuktoyaktuk
# {'coord': {'lon': -133.0374, 'lat': 69.4541}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': -31, 'feels_like': -42.61, 'temp_min': -31, 'temp_max': -31, 'pressure': 1037, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 240}, 'clouds': {'all': 75}, 'dt': 1612567398, 'sys': {'type': 1, 'id': 942, 'country': 'CA', 'sunrise': 1612548416, 'sunset': 1612569928}, 'timezone': -25200, 'id': 6170031, 'name': 'Tuktoyaktuk', 'cod': 200}
# Processing Record 11 of Set 1 | mahebourg
# {'coord': {'lon': 57.7, 'lat': -20.4081}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 77, 'feels_like': 83.43, 'temp_min': 77, 'temp_max': 77, 'pressure': 1013, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 330}, 'rain': {'1h': 0.24}, 'clouds': {'all': 75}, 'dt': 1612567402, 'sys': {'type': 1, 'id': 2061, 'country': 'MU', 'sunrise': 1612576544, 'sunset': 1612623051}, 'timezone': 14400, 'id': 934322, 'name': 'Mahébourg', 'cod': 200}
# Processing Record 12 of Set 1 | vaini
# {'coord': {'lon': -175.2, 'lat': -21.2}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 84.2, 'feels_like': 93.02, 'temp_min': 84.2, 'temp_max': 84.2, 'pressure': 1006, 'humidity': 84}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 80}, 'clouds': {'all': 75}, 'dt': 1612567397, 'sys': {'type': 1, 'id': 7285, 'country': 'TO', 'sunrise': 1612632401, 'sunset': 1612678992}, 'timezone': 46800, 'id': 4032243, 'name': 'Vaini', 'cod': 200}
# Processing Record 13 of Set 1 | esperance
# {'coord': {'lon': 121.9, 'lat': -33.8667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 60.8, 'feels_like': 59.2, 'temp_min': 60.8, 'temp_max': 60.8, 'pressure': 1016, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 130}, 'clouds': {'all': 90}, 'dt': 1612567451, 'sys': {'type': 1, 'id': 9525, 'country': 'AU', 'sunrise': 1612559933, 'sunset': 1612608845}, 'timezone': 28800, 'id': 2071860, 'name': 'Esperance', 'cod': 200}
# Processing Record 14 of Set 1 | mataura
# {'coord': {'lon': 168.8643, 'lat': -46.1927}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 70.95, 'feels_like': 70.56, 'temp_min': 70.95, 'temp_max': 70.95, 'pressure': 1021, 'humidity': 51, 'sea_level': 1021, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 1.79, 'deg': 224}, 'clouds': {'all': 54}, 'dt': 1612567631, 'sys': {'country': 'NZ', 'sunrise': 1612547114, 'sunset': 1612599119}, 'timezone': 46800, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# Processing Record 15 of Set 1 | mar del plata
# {'coord': {'lon': -57.5575, 'lat': -38.0023}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 71.62, 'feels_like': 68.86, 'temp_min': 69.8, 'temp_max': 73.99, 'pressure': 1011, 'humidity': 49}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 50}, 'clouds': {'all': 0}, 'dt': 1612567507, 'sys': {'type': 1, 'id': 8305, 'country': 'AR', 'sunrise': 1612516118, 'sunset': 1612565994}, 'timezone': -10800, 'id': 3430863, 'name': 'Mar del Plata', 'cod': 200}
# Processing Record 16 of Set 1 | pisco
# {'coord': {'lon': -76.2167, 'lat': -13.7}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 70.93, 'feels_like': 66.72, 'temp_min': 70, 'temp_max': 71.6, 'pressure': 1010, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 17.27, 'deg': 220}, 'clouds': {'all': 0}, 'dt': 1612567411, 'sys': {'type': 1, 'id': 8691, 'country': 'PE', 'sunrise': 1612522772, 'sunset': 1612568297}, 'timezone': -18000, 'id': 3932145, 'name': 'Pisco', 'cod': 200}
# Processing Record 17 of Set 1 | emba
# {'coord': {'lon': 58.1442, 'lat': 48.8264}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 35.24, 'feels_like': 23.76, 'temp_min': 35.24, 'temp_max': 35.24, 'pressure': 1003, 'humidity': 92, 'sea_level': 1003, 'grnd_level': 975}, 'visibility': 10000, 'wind': {'speed': 14.36, 'deg': 158}, 'clouds': {'all': 100}, 'dt': 1612567631, 'sys': {'country': 'KZ', 'sunrise': 1612582229, 'sunset': 1612617153}, 'timezone': 18000, 'id': 609924, 'name': 'Emba', 'cod': 200}
# Processing Record 18 of Set 1 | phan rang
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 19 of Set 1 | attawapiskat
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 20 of Set 1 | banjar
# {'coord': {'lon': 114.9675, 'lat': -8.19}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 78.8, 'feels_like': 86.72, 'temp_min': 78.8, 'temp_max': 78.8, 'pressure': 1008, 'humidity': 89}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 10}, 'rain': {'1h': 0.55}, 'clouds': {'all': 40}, 'dt': 1612567631, 'sys': {'type': 1, 'id': 9333, 'country': 'ID', 'sunrise': 1612563689, 'sunset': 1612608416}, 'timezone': 28800, 'id': 1650232, 'name': 'Banjar', 'cod': 200}
# Processing Record 21 of Set 1 | nadadores
# {'coord': {'lon': -101.6, 'lat': 27.05}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.01, 'feels_like': 74.12, 'temp_min': 80.01, 'temp_max': 80.01, 'pressure': 1020, 'humidity': 20}, 'visibility': 10000, 'wind': {'speed': 5.01, 'deg': 76}, 'clouds': {'all': 0}, 'dt': 1612567632, 'sys': {'type': 3, 'id': 2032764, 'country': 'MX', 'sunrise': 1612531782, 'sunset': 1612571471}, 'timezone': -21600, 'id': 3995154, 'name': 'Nadadores', 'cod': 200}
# Processing Record 22 of Set 1 | busselton
# {'coord': {'lon': 115.3333, 'lat': -33.65}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 59.63, 'feels_like': 59.27, 'temp_min': 59, 'temp_max': 60.01, 'pressure': 1015, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 150, 'gust': 5.99}, 'clouds': {'all': 94}, 'dt': 1612567364, 'sys': {'type': 3, 'id': 2008303, 'country': 'AU', 'sunrise': 1612561532, 'sunset': 1612610398}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# Processing Record 23 of Set 1 | fort saint james
# {'coord': {'lon': -124.25, 'lat': 54.4333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 27.36, 'feels_like': 22.23, 'temp_min': 27.36, 'temp_max': 27.36, 'pressure': 1023, 'humidity': 96, 'sea_level': 1023, 'grnd_level': 938}, 'visibility': 6915, 'wind': {'speed': 1.45, 'deg': 161}, 'clouds': {'all': 100}, 'dt': 1612567632, 'sys': {'country': 'CA', 'sunrise': 1612540654, 'sunset': 1612573472}, 'timezone': -28800, 'id': 5881688, 'name': 'Fort Saint James', 'cod': 200}
# Processing Record 24 of Set 1 | hobart
# {'coord': {'lon': 147.3294, 'lat': -42.8794}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 68.92, 'feels_like': 68.34, 'temp_min': 66.99, 'temp_max': 71.01, 'pressure': 993, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 330}, 'rain': {'1h': 0.28}, 'clouds': {'all': 75}, 'dt': 1612567632, 'sys': {'type': 1, 'id': 9545, 'country': 'AU', 'sunrise': 1612552766, 'sunset': 1612603804}, 'timezone': 39600, 'id': 2163355, 'name': 'Hobart', 'cod': 200}
# Processing Record 25 of Set 1 | vaitape
# {'coord': {'lon': -151.75, 'lat': -16.5167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 81.55, 'feels_like': 86.05, 'temp_min': 81.55, 'temp_max': 81.55, 'pressure': 1009, 'humidity': 63, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 3.58, 'deg': 48}, 'clouds': {'all': 1}, 'dt': 1612567632, 'sys': {'country': 'PF', 'sunrise': 1612540697, 'sunset': 1612586630}, 'timezone': -36000, 'id': 4033077, 'name': 'Vaitape', 'cod': 200}
# Processing Record 26 of Set 1 | bluff
# {'coord': {'lon': 168.3333, 'lat': -46.6}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 58.91, 'feels_like': 57.24, 'temp_min': 58.91, 'temp_max': 58.91, 'pressure': 1021, 'humidity': 74, 'sea_level': 1021, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 3.42, 'deg': 271}, 'clouds': {'all': 66}, 'dt': 1612567370, 'sys': {'country': 'NZ', 'sunrise': 1612547179, 'sunset': 1612599309}, 'timezone': 46800, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# Processing Record 27 of Set 1 | tera
# {'coord': {'lon': 0.7531, 'lat': 14.0078}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 77.67, 'feels_like': 68.14, 'temp_min': 77.67, 'temp_max': 77.67, 'pressure': 1012, 'humidity': 17, 'sea_level': 1012, 'grnd_level': 984}, 'visibility': 10000, 'wind': {'speed': 9.91, 'deg': 78}, 'clouds': {'all': 20}, 'dt': 1612567633, 'sys': {'country': 'NE', 'sunrise': 1612592607, 'sunset': 1612634324}, 'timezone': 3600, 'id': 2438855, 'name': 'Téra', 'cod': 200}
# Processing Record 28 of Set 1 | mahibadhoo
# {'coord': {'lon': 72.9667, 'lat': 3.7833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 81.1, 'feels_like': 83.8, 'temp_min': 81.1, 'temp_max': 81.1, 'pressure': 1009, 'humidity': 71, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 9.46, 'deg': 9}, 'clouds': {'all': 87}, 'dt': 1612567394, 'sys': {'country': 'MV', 'sunrise': 1612574580, 'sunset': 1612617686}, 'timezone': 18000, 'id': 1337605, 'name': 'Mahibadhoo', 'cod': 200}
# Processing Record 29 of Set 1 | ndele
# {'coord': {'lon': 20.6473, 'lat': 8.4109}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 76.86, 'feels_like': 68.31, 'temp_min': 76.86, 'temp_max': 76.86, 'pressure': 1010, 'humidity': 19, 'sea_level': 1010, 'grnd_level': 954}, 'visibility': 10000, 'wind': {'speed': 8.7, 'deg': 62}, 'clouds': {'all': 14}, 'dt': 1612567633, 'sys': {'country': 'CF', 'sunrise': 1612587448, 'sunset': 1612629933}, 'timezone': 3600, 'id': 237379, 'name': 'Ndélé', 'cod': 200}
# Processing Record 30 of Set 1 | bulalacao
# {'coord': {'lon': 121.3435, 'lat': 12.3254}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 78.58, 'feels_like': 76.89, 'temp_min': 78.58, 'temp_max': 78.58, 'pressure': 1011, 'humidity': 78, 'sea_level': 1011, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 17.6, 'deg': 34}, 'clouds': {'all': 77}, 'dt': 1612567633, 'sys': {'country': 'PH', 'sunrise': 1612563553, 'sunset': 1612605492}, 'timezone': 28800, 'id': 1723002, 'name': 'Bulalacao', 'cod': 200}
# Processing Record 31 of Set 1 | marystown
# {'coord': {'lon': -55.1483, 'lat': 47.1666}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 34.79, 'feels_like': 21.4, 'temp_min': 34.79, 'temp_max': 34.79, 'pressure': 1010, 'humidity': 88, 'sea_level': 1010, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 17.31, 'deg': 262}, 'clouds': {'all': 96}, 'dt': 1612567451, 'sys': {'country': 'CA', 'sunrise': 1612522828, 'sunset': 1612558128}, 'timezone': -12600, 'id': 6067472, 'name': 'Marystown', 'cod': 200}
# Processing Record 32 of Set 1 | tasiilaq
# {'coord': {'lon': -37.6368, 'lat': 65.6145}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 24.8, 'feels_like': 17.65, 'temp_min': 24.8, 'temp_max': 24.8, 'pressure': 1020, 'humidity': 50}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 0}, 'clouds': {'all': 75}, 'dt': 1612567633, 'sys': {'type': 1, 'id': 81, 'country': 'GL', 'sunrise': 1612523333, 'sunset': 1612549216}, 'timezone': -10800, 'id': 3424607, 'name': 'Tasiilaq', 'cod': 200}
# Processing Record 33 of Set 1 | burnie
# {'coord': {'lon': 145.9167, 'lat': -41.0667}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 66, 'feels_like': 63.5, 'temp_min': 66, 'temp_max': 66, 'pressure': 1008, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 13, 'deg': 330}, 'clouds': {'all': 35}, 'dt': 1612567633, 'sys': {'type': 3, 'id': 50154, 'country': 'AU', 'sunrise': 1612553343, 'sunset': 1612603905}, 'timezone': 39600, 'id': 2173125, 'name': 'Burnie', 'cod': 200}
# Processing Record 34 of Set 1 | puerto ayora
# {'coord': {'lon': -90.3518, 'lat': -0.7393}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 79.61, 'feels_like': 84.29, 'temp_min': 78.01, 'temp_max': 82.4, 'pressure': 1009, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 120}, 'clouds': {'all': 40}, 'dt': 1612567394, 'sys': {'type': 1, 'id': 8521, 'country': 'EC', 'sunrise': 1612527070, 'sunset': 1612570784}, 'timezone': -21600, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# Processing Record 35 of Set 1 | anantapur
# {'coord': {'lon': 77.6, 'lat': 14.6833}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 64.35, 'feels_like': 63.5, 'temp_min': 64.35, 'temp_max': 64.35, 'pressure': 1012, 'humidity': 69, 'sea_level': 1012, 'grnd_level': 972}, 'visibility': 10000, 'wind': {'speed': 3.67, 'deg': 102}, 'clouds': {'all': 8}, 'dt': 1612567435, 'sys': {'country': 'IN', 'sunrise': 1612574215, 'sunset': 1612615827}, 'timezone': 19800, 'id': 1278672, 'name': 'Anantapur', 'cod': 200}
# Processing Record 36 of Set 1 | georgetown
# {'coord': {'lon': 100.3354, 'lat': 5.4112}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 77.47, 'feels_like': 82.35, 'temp_min': 77, 'temp_max': 79, 'pressure': 1010, 'humidity': 83}, 'visibility': 9000, 'wind': {'speed': 6.62, 'deg': 74}, 'clouds': {'all': 20}, 'dt': 1612567634, 'sys': {'type': 1, 'id': 9429, 'country': 'MY', 'sunrise': 1612568121, 'sunset': 1612611008}, 'timezone': 28800, 'id': 1735106, 'name': 'George Town', 'cod': 200}
# Processing Record 37 of Set 1 | kavieng
# {'coord': {'lon': 150.7967, 'lat': -2.5744}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 82.22, 'feels_like': 87.93, 'temp_min': 82.22, 'temp_max': 82.22, 'pressure': 1009, 'humidity': 74, 'sea_level': 1009, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 6.33, 'deg': 70}, 'clouds': {'all': 96}, 'dt': 1612567634, 'sys': {'country': 'PG', 'sunrise': 1612555472, 'sunset': 1612599434}, 'timezone': 36000, 'id': 2094342, 'name': 'Kavieng', 'cod': 200}
# Processing Record 38 of Set 1 | aksarka
# {'coord': {'lon': 67.7975, 'lat': 66.5606}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': -20.54, 'feels_like': -35.3, 'temp_min': -20.54, 'temp_max': -20.54, 'pressure': 1008, 'humidity': 87, 'sea_level': 1008, 'grnd_level': 1005}, 'visibility': 328, 'wind': {'speed': 13.91, 'deg': 37}, 'snow': {'1h': 0.11}, 'clouds': {'all': 100}, 'dt': 1612567418, 'sys': {'country': 'RU', 'sunrise': 1612584736, 'sunset': 1612610012}, 'timezone': 18000, 'id': 1512019, 'name': 'Aksarka', 'cod': 200}
# Processing Record 39 of Set 1 | qui nhon
# {'coord': {'lon': 109.2333, 'lat': 13.7667}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 68.61, 'feels_like': 69.82, 'temp_min': 68.61, 'temp_max': 68.61, 'pressure': 1015, 'humidity': 90, 'sea_level': 1015, 'grnd_level': 1015}, 'visibility': 7842, 'wind': {'speed': 7.7, 'deg': 324}, 'clouds': {'all': 43}, 'dt': 1612567428, 'sys': {'country': 'VN', 'sunrise': 1612566560, 'sunset': 1612608298}, 'timezone': 25200, 'id': 1568574, 'name': 'Qui Nhon', 'cod': 200}
# Processing Record 40 of Set 1 | saleaula
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 41 of Set 1 | belushya guba
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 42 of Set 1 | lazaro cardenas
# {'coord': {'lon': -102.2, 'lat': 17.9583}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.19, 'feels_like': 82.62, 'temp_min': 80.19, 'temp_max': 80.19, 'pressure': 1009, 'humidity': 64, 'sea_level': 1009, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 6.55, 'deg': 197}, 'clouds': {'all': 1}, 'dt': 1612567467, 'sys': {'country': 'MX', 'sunrise': 1612531213, 'sunset': 1612572329}, 'timezone': -21600, 'id': 4026082, 'name': 'Lázaro Cárdenas', 'cod': 200}
# Processing Record 43 of Set 1 | airai
# {'coord': {'lon': 125.4092, 'lat': -8.9266}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 62.24, 'feels_like': 64.47, 'temp_min': 62.24, 'temp_max': 62.24, 'pressure': 1008, 'humidity': 100, 'sea_level': 1008, 'grnd_level': 854}, 'visibility': 10000, 'wind': {'speed': 3.4, 'deg': 290}, 'clouds': {'all': 100}, 'dt': 1612567635, 'sys': {'country': 'TL', 'sunrise': 1612561131, 'sunset': 1612605962}, 'timezone': 32400, 'id': 1651810, 'name': 'Airai', 'cod': 200}
# Processing Record 44 of Set 1 | nikolskoye
# {'coord': {'lon': 30.7861, 'lat': 59.7035}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 8.64, 'feels_like': -3.82, 'temp_min': 6.8, 'temp_max': 12, 'pressure': 1017, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 11.18, 'deg': 320}, 'snow': {'1h': 0.37}, 'clouds': {'all': 75}, 'dt': 1612567379, 'sys': {'type': 1, 'id': 8926, 'country': 'RU', 'sunrise': 1612591035, 'sunset': 1612621480}, 'timezone': 10800, 'id': 546105, 'name': 'Nikolskoye', 'cod': 200}
# Processing Record 45 of Set 1 | salalah
# {'coord': {'lon': 54.0924, 'lat': 17.0151}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 73.4, 'feels_like': 72.95, 'temp_min': 73.4, 'temp_max': 73.4, 'pressure': 1015, 'humidity': 60}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 160}, 'clouds': {'all': 20}, 'dt': 1612567635, 'sys': {'type': 1, 'id': 7562, 'country': 'OM', 'sunrise': 1612580023, 'sunset': 1612621304}, 'timezone': 14400, 'id': 286621, 'name': 'Salalah', 'cod': 200}
# Processing Record 46 of Set 1 | kahului
# {'coord': {'lon': -156.47, 'lat': 20.8947}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 70, 'feels_like': 65.82, 'temp_min': 68, 'temp_max': 73.4, 'pressure': 1011, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 360}, 'clouds': {'all': 40}, 'dt': 1612567635, 'sys': {'type': 1, 'id': 7879, 'country': 'US', 'sunrise': 1612544455, 'sunset': 1612585138}, 'timezone': -36000, 'id': 5847411, 'name': 'Kahului', 'cod': 200}
# Processing Record 47 of Set 1 | sayyan
# {'coord': {'lon': 44.3244, 'lat': 15.1718}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 48.24, 'feels_like': 42.66, 'temp_min': 48.24, 'temp_max': 48.24, 'pressure': 1014, 'humidity': 68, 'sea_level': 1014, 'grnd_level': 758}, 'visibility': 10000, 'wind': {'speed': 5.37, 'deg': 245}, 'clouds': {'all': 9}, 'dt': 1612567636, 'sys': {'country': 'YE', 'sunrise': 1612582234, 'sunset': 1612623781}, 'timezone': 10800, 'id': 70979, 'name': 'Sayyan', 'cod': 200}
# Processing Record 48 of Set 1 | norman wells
# {'coord': {'lon': -126.8329, 'lat': 65.282}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': -27.4, 'feels_like': -35.75, 'temp_min': -27.4, 'temp_max': -27.4, 'pressure': 1041, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 290}, 'clouds': {'all': 75}, 'dt': 1612567271, 'sys': {'type': 1, 'id': 951, 'country': 'CA', 'sunrise': 1612544535, 'sunset': 1612570831}, 'timezone': -25200, 'id': 6089245, 'name': 'Norman Wells', 'cod': 200}
# Processing Record 49 of Set 1 | jamestown
# {'coord': {'lon': -79.2353, 'lat': 42.097}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 23.25, 'feels_like': 9.21, 'temp_min': 21.2, 'temp_max': 25, 'pressure': 1003, 'humidity': 63}, 'visibility': 10000, 'wind': {'speed': 14.97, 'deg': 230}, 'snow': {'1h': 0.15}, 'clouds': {'all': 90}, 'dt': 1612567346, 'sys': {'type': 1, 'id': 4588, 'country': 'US', 'sunrise': 1612527924, 'sunset': 1612564594}, 'timezone': -18000, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# Processing Record 50 of Set 1 | najran
# {'coord': {'lon': 44.1277, 'lat': 17.4924}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 64.4, 'feels_like': 54.57, 'temp_min': 64.4, 'temp_max': 64.4, 'pressure': 1014, 'humidity': 27}, 'visibility': 10000, 'wind': {'speed': 10.54, 'deg': 246}, 'clouds': {'all': 0}, 'dt': 1612567466, 'sys': {'type': 1, 'id': 7421, 'country': 'SA', 'sunrise': 1612582448, 'sunset': 1612623662}, 'timezone': 10800, 'id': 103630, 'name': 'Najrān', 'cod': 200}
# Processing Record 1 of Set 2 | gorontalo
# {'coord': {'lon': 123.0595, 'lat': 0.5412}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 76.5, 'feels_like': 84.34, 'temp_min': 76.5, 'temp_max': 76.5, 'pressure': 1009, 'humidity': 88, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 9879, 'wind': {'speed': 2.13, 'deg': 2}, 'clouds': {'all': 100}, 'dt': 1612567636, 'sys': {'country': 'ID', 'sunrise': 1612562340, 'sunset': 1612605881}, 'timezone': 28800, 'id': 1643837, 'name': 'Gorontalo', 'cod': 200}
# Processing Record 2 of Set 2 | mpophomeni
# {'coord': {'lon': 30.1862, 'lat': -29.5682}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 71.01, 'feels_like': 77.67, 'temp_min': 71.01, 'temp_max': 71.01, 'pressure': 1014, 'humidity': 95}, 'visibility': 10000, 'wind': {'speed': 1.3, 'deg': 26}, 'clouds': {'all': 100}, 'dt': 1612567636, 'sys': {'type': 3, 'id': 2002439, 'country': 'ZA', 'sunrise': 1612582376, 'sunset': 1612630426}, 'timezone': 7200, 'id': 973139, 'name': 'Mpophomeni', 'cod': 200}
# Processing Record 3 of Set 2 | luanda
# {'coord': {'lon': 13.2343, 'lat': -8.8368}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 78.8, 'feels_like': 82.92, 'temp_min': 78.8, 'temp_max': 78.8, 'pressure': 1010, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 170}, 'clouds': {'all': 0}, 'dt': 1612567488, 'sys': {'type': 1, 'id': 2173, 'country': 'AO', 'sunrise': 1612588065, 'sunset': 1612632875}, 'timezone': 3600, 'id': 2240449, 'name': 'Luanda', 'cod': 200}
# Processing Record 4 of Set 2 | saint george
# {'coord': {'lon': -113.5841, 'lat': 37.1041}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 59.13, 'feels_like': 40.66, 'temp_min': 57.2, 'temp_max': 61, 'pressure': 1014, 'humidity': 23}, 'visibility': 10000, 'wind': {'speed': 24.16, 'deg': 250}, 'clouds': {'all': 1}, 'dt': 1612567524, 'sys': {'type': 1, 'id': 5832, 'country': 'US', 'sunrise': 1612535596, 'sunset': 1612573410}, 'timezone': -25200, 'id': 5546220, 'name': 'Saint George', 'cod': 200}
# Processing Record 5 of Set 2 | mount isa
# {'coord': {'lon': 139.5, 'lat': -20.7333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.6, 'feels_like': 76.37, 'temp_min': 80.6, 'temp_max': 80.6, 'pressure': 1007, 'humidity': 54}, 'visibility': 10000, 'wind': {'speed': 14.97, 'deg': 180}, 'clouds': {'all': 100}, 'dt': 1612567637, 'sys': {'type': 1, 'id': 9495, 'country': 'AU', 'sunrise': 1612556879, 'sunset': 1612603450}, 'timezone': 36000, 'id': 2065594, 'name': 'Mount Isa', 'cod': 200}
# Processing Record 6 of Set 2 | cancun
# {'coord': {'lon': -86.8466, 'lat': 21.1743}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 79.84, 'feels_like': 79.09, 'temp_min': 79, 'temp_max': 80.6, 'pressure': 1010, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 150}, 'clouds': {'all': 40}, 'dt': 1612567589, 'sys': {'type': 1, 'id': 7177, 'country': 'MX', 'sunrise': 1612527771, 'sunset': 1612568400}, 'timezone': -18000, 'id': 3531673, 'name': 'Cancún', 'cod': 200}
# Processing Record 7 of Set 2 | nouakchott
# {'coord': {'lon': -15.9785, 'lat': 18.0858}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 64.4, 'feels_like': 56.89, 'temp_min': 64.4, 'temp_max': 64.4, 'pressure': 1016, 'humidity': 77}, 'visibility': 7000, 'wind': {'speed': 17.27, 'deg': 340}, 'clouds': {'all': 88}, 'dt': 1612567637, 'sys': {'type': 1, 'id': 2482, 'country': 'MR', 'sunrise': 1612510534, 'sunset': 1612551619}, 'timezone': 0, 'id': 2377450, 'name': 'Nouakchott', 'cod': 200}
# Processing Record 8 of Set 2 | barrow
# {'coord': {'lon': -156.7887, 'lat': 71.2906}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': -7.6, 'feels_like': -20.83, 'temp_min': -7.6, 'temp_max': -7.6, 'pressure': 1034, 'humidity': 71}, 'visibility': 1207, 'wind': {'speed': 11.5, 'deg': 320}, 'clouds': {'all': 90}, 'dt': 1612567637, 'sys': {'type': 1, 'id': 7649, 'country': 'US', 'sunrise': 1612555674, 'sunset': 1612574072}, 'timezone': -32400, 'id': 5880054, 'name': 'Barrow', 'cod': 200}
# Processing Record 9 of Set 2 | bethel
# {'coord': {'lon': -73.414, 'lat': 41.3712}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 34.56, 'feels_like': 27.75, 'temp_min': 34, 'temp_max': 36, 'pressure': 1000, 'humidity': 91}, 'visibility': 387, 'wind': {'speed': 5.79, 'deg': 248}, 'clouds': {'all': 100}, 'dt': 1612567637, 'sys': {'type': 3, 'id': 2004826, 'country': 'US', 'sunrise': 1612526440, 'sunset': 1612563283}, 'timezone': -18000, 'id': 5282297, 'name': 'Bethel', 'cod': 200}
# Processing Record 10 of Set 2 | nhulunbuy
# {'coord': {'lon': 136.7667, 'lat': -12.2333}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 78.8, 'feels_like': 83.48, 'temp_min': 78.8, 'temp_max': 78.8, 'pressure': 1002, 'humidity': 89}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 250}, 'rain': {'1h': 0.24}, 'clouds': {'all': 90}, 'dt': 1612567637, 'sys': {'type': 1, 'id': 9576, 'country': 'AU', 'sunrise': 1612558171, 'sunset': 1612603469}, 'timezone': 34200, 'id': 2064735, 'name': 'Nhulunbuy', 'cod': 200}
# Processing Record 11 of Set 2 | saskylakh
# {'coord': {'lon': 114.0833, 'lat': 71.9167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -29.67, 'feels_like': -39.91, 'temp_min': -29.67, 'temp_max': -29.67, 'pressure': 1020, 'humidity': 84, 'sea_level': 1020, 'grnd_level': 1019}, 'visibility': 6011, 'wind': {'speed': 5.7, 'deg': 54}, 'clouds': {'all': 90}, 'dt': 1612567377, 'sys': {'country': 'RU', 'sunrise': 1612577634, 'sunset': 1612594895}, 'timezone': 32400, 'id': 2017155, 'name': 'Saskylakh', 'cod': 200}
# Processing Record 12 of Set 2 | zhongshu
# {'coord': {'lon': 103.7667, 'lat': 24.5167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 50.11, 'feels_like': 47.8, 'temp_min': 50.11, 'temp_max': 50.11, 'pressure': 1016, 'humidity': 91, 'sea_level': 1016, 'grnd_level': 831}, 'visibility': 10000, 'wind': {'speed': 3.11, 'deg': 174}, 'clouds': {'all': 98}, 'dt': 1612567638, 'sys': {'country': 'CN', 'sunrise': 1612568672, 'sunset': 1612608809}, 'timezone': 28800, 'id': 1784310, 'name': 'Zhongshu', 'cod': 200}
# Processing Record 13 of Set 2 | kapaa
# {'coord': {'lon': -159.319, 'lat': 22.0752}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 69.8, 'feels_like': 69.49, 'temp_min': 69.8, 'temp_max': 69.8, 'pressure': 1012, 'humidity': 60}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 0}, 'clouds': {'all': 75}, 'dt': 1612567383, 'sys': {'type': 1, 'id': 7873, 'country': 'US', 'sunrise': 1612545229, 'sunset': 1612585731}, 'timezone': -36000, 'id': 5848280, 'name': 'Kapaa', 'cod': 200}
# Processing Record 14 of Set 2 | mount gambier
# {'coord': {'lon': 140.7667, 'lat': -37.8333}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 62.6, 'feels_like': 55.89, 'temp_min': 62.6, 'temp_max': 62.6, 'pressure': 1000, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 250}, 'clouds': {'all': 40}, 'dt': 1612567347, 'sys': {'type': 1, 'id': 9560, 'country': 'AU', 'sunrise': 1612554971, 'sunset': 1612604750}, 'timezone': 37800, 'id': 2156643, 'name': 'Mount Gambier', 'cod': 200}
# Processing Record 15 of Set 2 | severo-kurilsk
# {'coord': {'lon': 156.125, 'lat': 50.6789}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 14.2, 'feels_like': 5.41, 'temp_min': 14.2, 'temp_max': 14.2, 'pressure': 1009, 'humidity': 84, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 5.37, 'deg': 261}, 'clouds': {'all': 51}, 'dt': 1612567406, 'sys': {'country': 'RU', 'sunrise': 1612559040, 'sunset': 1612593309}, 'timezone': 39600, 'id': 2121385, 'name': "Severo-Kuril'sk", 'cod': 200}
# Processing Record 16 of Set 2 | hermanus
# {'coord': {'lon': 19.2345, 'lat': -34.4187}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 68, 'feels_like': 71.73, 'temp_min': 68, 'temp_max': 68, 'pressure': 1016, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 104, 'gust': 5.99}, 'clouds': {'all': 5}, 'dt': 1612567397, 'sys': {'type': 3, 'id': 2006131, 'country': 'ZA', 'sunrise': 1612584533, 'sunset': 1612633527}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# Processing Record 17 of Set 2 | san vicente
# {'coord': {'lon': -54.1333, 'lat': -26.6167}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 65.34, 'feels_like': 63.48, 'temp_min': 65.34, 'temp_max': 65.34, 'pressure': 1010, 'humidity': 63, 'sea_level': 1010, 'grnd_level': 943}, 'visibility': 10000, 'wind': {'speed': 4.63, 'deg': 164}, 'rain': {'1h': 0.115}, 'clouds': {'all': 0}, 'dt': 1612567638, 'sys': {'country': 'AR', 'sunrise': 1612516442, 'sunset': 1612564026}, 'timezone': -10800, 'id': 3428068, 'name': 'San Vicente', 'cod': 200}
# Processing Record 18 of Set 2 | vila franca do campo
# {'coord': {'lon': -25.4333, 'lat': 37.7167}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 54.86, 'feels_like': 53.91, 'temp_min': 53.6, 'temp_max': 55.99, 'pressure': 1027, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 340}, 'clouds': {'all': 75}, 'dt': 1612567639, 'sys': {'type': 1, 'id': 6899, 'country': 'PT', 'sunrise': 1612514519, 'sunset': 1612552172}, 'timezone': -3600, 'id': 3372472, 'name': 'Vila Franca do Campo', 'cod': 200}
# Processing Record 19 of Set 2 | korla
# {'coord': {'lon': 86.1469, 'lat': 41.7597}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 25.77, 'feels_like': 19.62, 'temp_min': 25.77, 'temp_max': 25.77, 'pressure': 1023, 'humidity': 82, 'sea_level': 1023, 'grnd_level': 909}, 'visibility': 10000, 'wind': {'speed': 2.24, 'deg': 112}, 'clouds': {'all': 0}, 'dt': 1612567639, 'sys': {'country': 'CN', 'sunrise': 1612574555, 'sunset': 1612611385}, 'timezone': 28800, 'id': 1529376, 'name': 'Korla', 'cod': 200}
# Processing Record 20 of Set 2 | lakes entrance
# {'coord': {'lon': 147.981, 'lat': -37.8811}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 75, 'feels_like': 69.22, 'temp_min': 75, 'temp_max': 75, 'pressure': 995, 'humidity': 53}, 'visibility': 10000, 'wind': {'speed': 14, 'deg': 310, 'gust': 21.99}, 'clouds': {'all': 1}, 'dt': 1612567639, 'sys': {'type': 3, 'id': 2003486, 'country': 'AU', 'sunrise': 1612553233, 'sunset': 1612603025}, 'timezone': 39600, 'id': 2160735, 'name': 'Lakes Entrance', 'cod': 200}
# Processing Record 21 of Set 2 | banon
# {'coord': {'lon': -1.1909, 'lat': 40.8382}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 51.8, 'feels_like': 41.47, 'temp_min': 51.8, 'temp_max': 51.8, 'pressure': 1003, 'humidity': 93}, 'visibility': 9000, 'wind': {'speed': 18.41, 'deg': 20, 'gust': 31.07}, 'clouds': {'all': 75}, 'dt': 1612567639, 'sys': {'type': 1, 'id': 6401, 'country': 'ES', 'sunrise': 1612595391, 'sunset': 1612632473}, 'timezone': 3600, 'id': 3128883, 'name': 'Bañón', 'cod': 200}
# Processing Record 22 of Set 2 | carnarvon
# {'coord': {'lon': 113.6333, 'lat': -24.8667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.6, 'feels_like': 76.91, 'temp_min': 80.6, 'temp_max': 80.6, 'pressure': 997, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 23.02, 'deg': 320}, 'clouds': {'all': 90}, 'dt': 1612567320, 'sys': {'type': 1, 'id': 9505, 'country': 'AU', 'sunrise': 1612562752, 'sunset': 1612609993}, 'timezone': 28800, 'id': 2074865, 'name': 'Carnarvon', 'cod': 200}
# Processing Record 23 of Set 2 | baykit
# {'coord': {'lon': 96.37, 'lat': 61.67}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -3.1, 'feels_like': -11.07, 'temp_min': -3.1, 'temp_max': -3.1, 'pressure': 1019, 'humidity': 88, 'sea_level': 1019, 'grnd_level': 999}, 'visibility': 2174, 'wind': {'speed': 2.59, 'deg': 235}, 'clouds': {'all': 100}, 'dt': 1612567639, 'sys': {'country': 'RU', 'sunrise': 1612575917, 'sunset': 1612605116}, 'timezone': 25200, 'id': 1510689, 'name': 'Baykit', 'cod': 200}
# Processing Record 24 of Set 2 | albany
# {'coord': {'lon': -73.9662, 'lat': 42.6001}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 35.85, 'feels_like': 28.78, 'temp_min': 33.01, 'temp_max': 37.99, 'pressure': 998, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 4.97, 'deg': 209}, 'clouds': {'all': 92}, 'dt': 1612567387, 'sys': {'type': 3, 'id': 19530, 'country': 'US', 'sunrise': 1612526722, 'sunset': 1612563266}, 'timezone': -18000, 'id': 5106841, 'name': 'Albany', 'cod': 200}
# Processing Record 25 of Set 2 | kautokeino
# {'coord': {'lon': 23.0412, 'lat': 69.0125}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 16.03, 'feels_like': 4.01, 'temp_min': 16.03, 'temp_max': 16.03, 'pressure': 1031, 'humidity': 93, 'sea_level': 1031, 'grnd_level': 989}, 'visibility': 10000, 'wind': {'speed': 11.63, 'deg': 339}, 'clouds': {'all': 69}, 'dt': 1612567640, 'sys': {'country': 'NO', 'sunrise': 1612596882, 'sunset': 1612619350}, 'timezone': 3600, 'id': 779330, 'name': 'Kautokeino', 'cod': 200}
# Processing Record 26 of Set 2 | kruisfontein
# {'coord': {'lon': 24.7314, 'lat': -34.0033}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 72, 'feels_like': 77.32, 'temp_min': 72, 'temp_max': 72, 'pressure': 1016, 'humidity': 86}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 109, 'gust': 5.99}, 'clouds': {'all': 33}, 'dt': 1612567640, 'sys': {'type': 3, 'id': 2035063, 'country': 'ZA', 'sunrise': 1612583255, 'sunset': 1612632166}, 'timezone': 7200, 'id': 986717, 'name': 'Kruisfontein', 'cod': 200}
# Processing Record 27 of Set 2 | provideniya
# {'coord': {'lon': -173.3, 'lat': 64.3833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 7.92, 'feels_like': -5.17, 'temp_min': 7.92, 'temp_max': 7.92, 'pressure': 1017, 'humidity': 92, 'sea_level': 1017, 'grnd_level': 1016}, 'visibility': 552, 'wind': {'speed': 12.57, 'deg': 24}, 'clouds': {'all': 100}, 'dt': 1612567640, 'sys': {'country': 'RU', 'sunrise': 1612641481, 'sunset': 1612669000}, 'timezone': 43200, 'id': 4031574, 'name': 'Provideniya', 'cod': 200}
# Processing Record 28 of Set 2 | tulsipur
# {'coord': {'lon': 82.2973, 'lat': 28.131}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 48.16, 'feels_like': 42.21, 'temp_min': 48.16, 'temp_max': 48.16, 'pressure': 1018, 'humidity': 65, 'sea_level': 1018, 'grnd_level': 939}, 'visibility': 10000, 'wind': {'speed': 5.64, 'deg': 28}, 'clouds': {'all': 0}, 'dt': 1612567640, 'sys': {'country': 'NP', 'sunrise': 1612574120, 'sunset': 1612613667}, 'timezone': 20700, 'id': 1282635, 'name': 'Tulsīpur', 'cod': 200}
# Processing Record 29 of Set 2 | ushuaia
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 46.4, 'feels_like': 29.77, 'temp_min': 46.4, 'temp_max': 46.4, 'pressure': 1016, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 25.32, 'deg': 230}, 'clouds': {'all': 75}, 'dt': 1612567363, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1612515963, 'sunset': 1612571305}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# Processing Record 30 of Set 2 | tsihombe
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 31 of Set 2 | maniwaki
# {'coord': {'lon': -75.966, 'lat': 46.3834}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 28.4, 'feels_like': 16.57, 'temp_min': 28.4, 'temp_max': 28.4, 'pressure': 998, 'humidity': 80}, 'visibility': 9991, 'wind': {'speed': 12.66, 'deg': 200, 'gust': 18.41}, 'clouds': {'all': 99}, 'dt': 1612567641, 'sys': {'type': 1, 'id': 371, 'country': 'CA', 'sunrise': 1612527705, 'sunset': 1612563243}, 'timezone': -18000, 'id': 6065262, 'name': 'Maniwaki', 'cod': 200}
# Processing Record 32 of Set 2 | puerto leguizamo
# {'coord': {'lon': -74.7819, 'lat': -0.1934}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 76.64, 'feels_like': 86.49, 'temp_min': 76.64, 'temp_max': 76.64, 'pressure': 1007, 'humidity': 93, 'sea_level': 1007, 'grnd_level': 986}, 'visibility': 10000, 'wind': {'speed': 0.36, 'deg': 116}, 'clouds': {'all': 91}, 'dt': 1612567641, 'sys': {'country': 'CO', 'sunrise': 1612523370, 'sunset': 1612567010}, 'timezone': -18000, 'id': 3671437, 'name': 'Caucayá', 'cod': 200}
# Processing Record 33 of Set 2 | westport
# {'coord': {'lon': -73.3579, 'lat': 41.1415}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 36.18, 'feels_like': 28.74, 'temp_min': 33.01, 'temp_max': 39, 'pressure': 1003, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 6.58, 'deg': 248}, 'clouds': {'all': 1}, 'dt': 1612567641, 'sys': {'type': 1, 'id': 3409, 'country': 'US', 'sunrise': 1612526399, 'sunset': 1612563297}, 'timezone': -18000, 'id': 4845585, 'name': 'Westport', 'cod': 200}
# Processing Record 34 of Set 2 | bathsheba
# {'coord': {'lon': -59.5167, 'lat': 13.2167}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 78.8, 'feels_like': 74.17, 'temp_min': 78.8, 'temp_max': 78.8, 'pressure': 1014, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 18.41, 'deg': 90}, 'clouds': {'all': 40}, 'dt': 1612567641, 'sys': {'type': 1, 'id': 8772, 'country': 'BB', 'sunrise': 1612520628, 'sunset': 1612562424}, 'timezone': -14400, 'id': 3374083, 'name': 'Bathsheba', 'cod': 200}
# Processing Record 35 of Set 2 | los llanos de aridane
# {'coord': {'lon': -17.9182, 'lat': 28.6585}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 54.84, 'feels_like': 42.35, 'temp_min': 51.01, 'temp_max': 60.8, 'pressure': 1018, 'humidity': 51}, 'visibility': 10000, 'wind': {'speed': 17.27, 'deg': 20}, 'clouds': {'all': 0}, 'dt': 1612567381, 'sys': {'type': 1, 'id': 2377, 'country': 'ES', 'sunrise': 1612511845, 'sunset': 1612551239}, 'timezone': 0, 'id': 2514651, 'name': 'Los Llanos de Aridane', 'cod': 200}
# Processing Record 36 of Set 2 | hamilton
# {'coord': {'lon': -84.5333, 'lat': 39.1834}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 34.79, 'feels_like': 22.41, 'temp_min': 34, 'temp_max': 36, 'pressure': 1008, 'humidity': 48}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 240, 'gust': 25.32}, 'clouds': {'all': 20}, 'dt': 1612567371, 'sys': {'type': 1, 'id': 3729, 'country': 'US', 'sunrise': 1612528854, 'sunset': 1612566207}, 'timezone': -18000, 'id': 4513583, 'name': 'Hamilton', 'cod': 200}
# Processing Record 37 of Set 2 | zaranj
# ...
# Processing Record 35 of Set 15 | akdepe
# {'coord': {'lon': 59.3788, 'lat': 42.0551}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 51.8, 'feels_like': 42.33, 'temp_min': 51.8, 'temp_max': 51.8, 'pressure': 1006, 'humidity': 54}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 200}, 'clouds': {'all': 0}, 'dt': 1612567738, 'sys': {'type': 1, 'id': 8993, 'country': 'TM', 'sunrise': 1612581009, 'sunset': 1612617780}, 'timezone': 18000, 'id': 601551, 'name': 'Akdepe', 'cod': 200}
# Processing Record 36 of Set 15 | tuggurt
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 37 of Set 15 | arawa
# {'coord': {'lon': 155.5367, 'lat': -6.2132}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 84.61, 'feels_like': 90.88, 'temp_min': 84.61, 'temp_max': 84.61, 'pressure': 1008, 'humidity': 68, 'sea_level': 1008, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 5.1, 'deg': 341}, 'clouds': {'all': 13}, 'dt': 1612567739, 'sys': {'country': 'PG', 'sunrise': 1612554087, 'sunset': 1612598544}, 'timezone': 39600, 'id': 2100633, 'name': 'Arawa', 'cod': 200}
# Processing Record 38 of Set 15 | silvan
# {'coord': {'lon': 41.0081, 'lat': 38.1419}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 35.6, 'feels_like': 31.42, 'temp_min': 35.6, 'temp_max': 35.6, 'pressure': 1019, 'humidity': 100}, 'visibility': 10000, 'wind': {'speed': 2.06, 'deg': 8}, 'clouds': {'all': 0}, 'dt': 1612567739, 'sys': {'type': 1, 'id': 6996, 'country': 'TR', 'sunrise': 1612584972, 'sunset': 1612622636}, 'timezone': 10800, 'id': 300796, 'name': 'Miepherkeim', 'cod': 200}
# Processing Record 39 of Set 15 | nebbi
# {'coord': {'lon': 31.0889, 'lat': 2.4783}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 73.92, 'feels_like': 68.77, 'temp_min': 73.92, 'temp_max': 73.92, 'pressure': 1010, 'humidity': 28, 'sea_level': 1010, 'grnd_level': 899}, 'visibility': 10000, 'wind': {'speed': 4.76, 'deg': 263}, 'clouds': {'all': 100}, 'dt': 1612567739, 'sys': {'country': 'UG', 'sunrise': 1612584543, 'sunset': 1612627826}, 'timezone': 10800, 'id': 227904, 'name': 'Nebbi', 'cod': 200}
# Processing Record 40 of Set 15 | antsohihy
# {'coord': {'lon': 47.9875, 'lat': -14.8796}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 74.8, 'feels_like': 82.6, 'temp_min': 74.8, 'temp_max': 74.8, 'pressure': 1010, 'humidity': 93, 'sea_level': 1010, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 2.17, 'deg': 127}, 'rain': {'1h': 0.24}, 'clouds': {'all': 81}, 'dt': 1612567739, 'sys': {'country': 'MG', 'sunrise': 1612579293, 'sunset': 1612624964}, 'timezone': 10800, 'id': 1068971, 'name': 'Antsohihy', 'cod': 200}
# Processing Record 41 of Set 15 | ayr
# {'coord': {'lon': -4.6339, 'lat': 55.4627}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 37.24, 'feels_like': 24.21, 'temp_min': 37, 'temp_max': 37.4, 'pressure': 1011, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 17.27, 'deg': 70}, 'rain': {'1h': 0.12}, 'clouds': {'all': 20}, 'dt': 1612567739, 'sys': {'type': 1, 'id': 1444, 'country': 'GB', 'sunrise': 1612512204, 'sunset': 1612544503}, 'timezone': 0, 'id': 2656708, 'name': 'Ayr', 'cod': 200}
# Processing Record 42 of Set 15 | cabedelo
# {'coord': {'lon': -34.8339, 'lat': -6.9811}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 78.8, 'feels_like': 84.88, 'temp_min': 78.8, 'temp_max': 78.8, 'pressure': 1012, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 80}, 'clouds': {'all': 20}, 'dt': 1612567739, 'sys': {'type': 1, 'id': 8391, 'country': 'BR', 'sunrise': 1612513316, 'sunset': 1612557888}, 'timezone': -10800, 'id': 3404558, 'name': 'Cabedelo', 'cod': 200}
# Processing Record 43 of Set 15 | zhoucheng
# {'coord': {'lon': 116.3117, 'lat': 35.9122}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 45, 'feels_like': 35.08, 'temp_min': 45, 'temp_max': 45, 'pressure': 1003, 'humidity': 1}, 'visibility': 10000, 'wind': {'speed': 4.92, 'deg': 257}, 'clouds': {'all': 0}, 'dt': 1612567740, 'sys': {'type': 3, 'id': 62766, 'country': 'CN', 'sunrise': 1612566679, 'sunset': 1612604781}, 'timezone': 28800, 'id': 1920772, 'name': 'Zhoucheng', 'cod': 200}
# Processing Record 44 of Set 15 | sao filipe
# {'coord': {'lon': -24.4956, 'lat': 14.8961}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 69.87, 'feels_like': 64.99, 'temp_min': 69.87, 'temp_max': 69.87, 'pressure': 1018, 'humidity': 75, 'sea_level': 1018, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 15.55, 'deg': 56}, 'clouds': {'all': 30}, 'dt': 1612567740, 'sys': {'country': 'CV', 'sunrise': 1612512344, 'sunset': 1612553897}, 'timezone': -3600, 'id': 3374210, 'name': 'São Filipe', 'cod': 200}
# Processing Record 45 of Set 15 | north platte
# {'coord': {'lon': -100.7654, 'lat': 41.1239}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 36.05, 'feels_like': 27.18, 'temp_min': 35.01, 'temp_max': 37.4, 'pressure': 1008, 'humidity': 52}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 80}, 'clouds': {'all': 1}, 'dt': 1612567740, 'sys': {'type': 1, 'id': 4674, 'country': 'US', 'sunrise': 1612532970, 'sunset': 1612569883}, 'timezone': -21600, 'id': 5697939, 'name': 'North Platte', 'cod': 200}
# Processing Record 46 of Set 15 | baft
# {'coord': {'lon': 56.6057, 'lat': 29.234}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 40.77, 'feels_like': 35.2, 'temp_min': 40.77, 'temp_max': 40.77, 'pressure': 1017, 'humidity': 56, 'sea_level': 1017, 'grnd_level': 775}, 'visibility': 10000, 'wind': {'speed': 2.19, 'deg': 82}, 'clouds': {'all': 11}, 'dt': 1612567740, 'sys': {'country': 'IR', 'sunrise': 1612580378, 'sunset': 1612619742}, 'timezone': 12600, 'id': 390054, 'name': 'Baft', 'cod': 200}
# Processing Record 47 of Set 15 | zurrieq
# {'coord': {'lon': 14.4742, 'lat': 35.8311}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 59.83, 'feels_like': 59.18, 'temp_min': 59, 'temp_max': 61, 'pressure': 1018, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 200}, 'clouds': {'all': 0}, 'dt': 1612567740, 'sys': {'type': 1, 'id': 6861, 'country': 'MT', 'sunrise': 1612591097, 'sunset': 1612629248}, 'timezone': 3600, 'id': 2562250, 'name': 'Żurrieq', 'cod': 200}
# Processing Record 48 of Set 15 | todos santos
# {'coord': {'lon': -110.2167, 'lat': 23.45}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 73.51, 'feels_like': 73.09, 'temp_min': 73, 'temp_max': 73.99, 'pressure': 1008, 'humidity': 71}, 'visibility': 10000, 'wind': {'speed': 8.99, 'deg': 313, 'gust': 17}, 'clouds': {'all': 5}, 'dt': 1612567741, 'sys': {'type': 3, 'id': 2004498, 'country': 'MX', 'sunrise': 1612533556, 'sunset': 1612573834}, 'timezone': -25200, 'id': 3981432, 'name': 'Todos Santos', 'cod': 200}
# Processing Record 49 of Set 15 | xuddur
# {'coord': {'lon': 43.8894, 'lat': 4.1213}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 67.24, 'feels_like': 62.69, 'temp_min': 67.24, 'temp_max': 67.24, 'pressure': 1011, 'humidity': 87, 'sea_level': 1011, 'grnd_level': 954}, 'visibility': 10000, 'wind': {'speed': 16.15, 'deg': 95}, 'clouds': {'all': 8}, 'dt': 1612567510, 'sys': {'country': 'SO', 'sunrise': 1612581581, 'sunset': 1612624643}, 'timezone': 10800, 'id': 49747, 'name': 'Oddur', 'cod': 200}
# Processing Record 50 of Set 15 | huaraz
# {'coord': {'lon': -77.5333, 'lat': -9.5333}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 57.43, 'feels_like': 54.28, 'temp_min': 57.43, 'temp_max': 57.43, 'pressure': 1013, 'humidity': 64, 'sea_level': 1013, 'grnd_level': 713}, 'visibility': 3738, 'wind': {'speed': 3.67, 'deg': 245}, 'rain': {'1h': 1.1}, 'clouds': {'all': 81}, 'dt': 1612567741, 'sys': {'country': 'PE', 'sunrise': 1612523387, 'sunset': 1612568314}, 'timezone': -18000, 'id': 3696378, 'name': 'Huaraz', 'cod': 200}
# Processing Record 1 of Set 16 | gazli
# {'coord': {'lon': 63.45, 'lat': 40.1333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 51.8, 'feels_like': 40.69, 'temp_min': 51.8, 'temp_max': 51.8, 'pressure': 1011, 'humidity': 43, 'sea_level': 1011, 'grnd_level': 989}, 'visibility': 10000, 'wind': {'speed': 12.88, 'deg': 178}, 'clouds': {'all': 100}, 'dt': 1612567741, 'sys': {'country': 'UZ', 'sunrise': 1612579808, 'sunset': 1612617026}, 'timezone': 18000, 'id': 1513990, 'name': 'Gazli', 'cod': 200}
# Processing Record 2 of Set 16 | darhan
# {'coord': {'lon': 105.9228, 'lat': 49.4867}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': -0.47, 'feels_like': -8.73, 'temp_min': -0.47, 'temp_max': -0.47, 'pressure': 1032, 'humidity': 85, 'sea_level': 1032, 'grnd_level': 943}, 'visibility': 10000, 'wind': {'speed': 3.2, 'deg': 182}, 'snow': {'1h': 0.4098}, 'clouds': {'all': 44}, 'dt': 1612567741, 'sys': {'country': 'MN', 'sunrise': 1612570878, 'sunset': 1612605568}, 'timezone': 28800, 'id': 2031964, 'name': 'Darhan', 'cod': 200}
# Processing Record 3 of Set 16 | malanje
# {'coord': {'lon': 16.341, 'lat': -9.5402}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 64.65, 'feels_like': 67.75, 'temp_min': 64.65, 'temp_max': 64.65, 'pressure': 1013, 'humidity': 92, 'sea_level': 1013, 'grnd_level': 888}, 'visibility': 10000, 'wind': {'speed': 1.88, 'deg': 270}, 'clouds': {'all': 100}, 'dt': 1612567741, 'sys': {'country': 'AO', 'sunrise': 1612587270, 'sunset': 1612632178}, 'timezone': 3600, 'id': 2239862, 'name': 'Malanje', 'cod': 200}
# Processing Record 4 of Set 16 | mutsamudu
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 5 of Set 16 | soverato
# {'coord': {'lon': 16.5499, 'lat': 38.685}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 54.46, 'feels_like': 50.2, 'temp_min': 51.8, 'temp_max': 57, 'pressure': 1017, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 50}, 'clouds': {'all': 20}, 'dt': 1612567742, 'sys': {'type': 1, 'id': 6701, 'country': 'IT', 'sunrise': 1612590896, 'sunset': 1612628452}, 'timezone': 3600, 'id': 2523045, 'name': 'Soverato Marina', 'cod': 200}
# Processing Record 6 of Set 16 | lozovo
# {'coord': {'lon': 21.9056, 'lat': 41.7839}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 35.6, 'feels_like': 31.66, 'temp_min': 35.6, 'temp_max': 35.6, 'pressure': 1019, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 1.14, 'deg': 40}, 'clouds': {'all': 0}, 'dt': 1612567742, 'sys': {'type': 1, 'id': 7023, 'country': 'MK', 'sunrise': 1612589963, 'sunset': 1612626814}, 'timezone': 3600, 'id': 790848, 'name': 'Lozovo', 'cod': 200}
# Processing Record 7 of Set 16 | mocuba
# {'coord': {'lon': 36.9856, 'lat': -16.8392}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 74.35, 'feels_like': 83.19, 'temp_min': 74.35, 'temp_max': 74.35, 'pressure': 1011, 'humidity': 97, 'sea_level': 1011, 'grnd_level': 994}, 'visibility': 10000, 'wind': {'speed': 1.12, 'deg': 92}, 'clouds': {'all': 100}, 'dt': 1612567742, 'sys': {'country': 'MZ', 'sunrise': 1612581790, 'sunset': 1612627748}, 'timezone': 7200, 'id': 1024312, 'name': 'Mocuba', 'cod': 200}
# Processing Record 8 of Set 16 | gibara
# {'coord': {'lon': -76.1317, 'lat': 21.1097}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 78.8, 'feels_like': 77.7, 'temp_min': 78.8, 'temp_max': 78.8, 'pressure': 1014, 'humidity': 73}, 'visibility': 9000, 'wind': {'speed': 14.97, 'deg': 70}, 'clouds': {'all': 40}, 'dt': 1612567742, 'sys': {'type': 1, 'id': 7241, 'country': 'CU', 'sunrise': 1612525195, 'sunset': 1612565832}, 'timezone': -18000, 'id': 3558315, 'name': 'Gibara', 'cod': 200}
# Processing Record 9 of Set 16 | goundam
# {'coord': {'lon': -3.6708, 'lat': 16.4145}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 77.85, 'feels_like': 70.45, 'temp_min': 77.85, 'temp_max': 77.85, 'pressure': 1011, 'humidity': 17, 'sea_level': 1011, 'grnd_level': 982}, 'visibility': 10000, 'wind': {'speed': 6.17, 'deg': 114}, 'clouds': {'all': 100}, 'dt': 1612567463, 'sys': {'country': 'ML', 'sunrise': 1612507458, 'sunset': 1612548787}, 'timezone': 0, 'id': 2456917, 'name': 'Goundam', 'cod': 200}
# Processing Record 10 of Set 16 | asyut
# {'coord': {'lon': 31.1837, 'lat': 27.181}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 55.4, 'feels_like': 49.12, 'temp_min': 55.4, 'temp_max': 55.4, 'pressure': 1023, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 290}, 'clouds': {'all': 0}, 'dt': 1612567742, 'sys': {'type': 1, 'id': 2510, 'country': 'EG', 'sunrise': 1612586303, 'sunset': 1612626021}, 'timezone': 7200, 'id': 359783, 'name': 'Assiut', 'cod': 200}
# Processing Record 11 of Set 16 | amahai
# {'coord': {'lon': 128.9167, 'lat': -3.3333}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.89, 'feels_like': 87.82, 'temp_min': 80.89, 'temp_max': 80.89, 'pressure': 1008, 'humidity': 76, 'sea_level': 1008, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 3.67, 'deg': 330}, 'clouds': {'all': 84}, 'dt': 1612567743, 'sys': {'country': 'ID', 'sunrise': 1612560673, 'sunset': 1612604736}, 'timezone': 32400, 'id': 1651591, 'name': 'Amahai', 'cod': 200}
# Processing Record 12 of Set 16 | kheralu
# {'coord': {'lon': 72.6167, 'lat': 23.8833}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 56.73, 'feels_like': 48.33, 'temp_min': 56.73, 'temp_max': 56.73, 'pressure': 1016, 'humidity': 36, 'sea_level': 1016, 'grnd_level': 995}, 'visibility': 10000, 'wind': {'speed': 8.1, 'deg': 33}, 'clouds': {'all': 0}, 'dt': 1612567743, 'sys': {'country': 'IN', 'sunrise': 1612576095, 'sunset': 1612616339}, 'timezone': 19800, 'id': 1266774, 'name': 'Kherālu', 'cod': 200}
# Processing Record 13 of Set 16 | awjilah
# {'coord': {'lon': 21.2869, 'lat': 29.1081}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 53.2, 'feels_like': 49.5, 'temp_min': 53.2, 'temp_max': 53.2, 'pressure': 1023, 'humidity': 59, 'sea_level': 1023, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 2.37, 'deg': 127}, 'clouds': {'all': 0}, 'dt': 1612567743, 'sys': {'country': 'LY', 'sunrise': 1612588840, 'sunset': 1612628234}, 'timezone': 7200, 'id': 88533, 'name': 'Awjilah', 'cod': 200}
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(cities)
# Out:
# 763

# %%
len(city_data)
# Out:
# 700

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea -23.1203 -134.9692     78.22        72          11
# 1       Horsham  51.0640   -0.3272     44.60        87          75
# 2  Longyearbyen  78.2186   15.6401     24.80        86          75
# 3      Flinders -34.5833  150.8552     70.00        91         100
# 4  Punta Arenas -53.1500  -70.9167     53.60        47           0
# 5          Hilo  19.7297 -155.0900     78.80        57           1
# 6     Tecoanapa  16.5167  -98.7500     81.63        65          24
# 7       Qaanaaq  77.4840  -69.3632     -6.68        76         100
# 8       Aklavik  68.2191 -135.0107    -32.80        75          20
# 9   Tuktoyaktuk  69.4541 -133.0374    -31.00        68          75
#
#    Wind Speed Country                 Date      Description
# 0       14.05      PF  2021-02-05 23:26:20       light rain
# 1        4.61      GB  2021-02-05 23:27:09    broken clouds
# 2        9.22      SJ  2021-02-05 23:25:13       light snow
# 3        8.99      AU  2021-02-05 23:25:13       light rain
# 4       26.46      CL  2021-02-05 23:27:09        clear sky
# 5       11.50      US  2021-02-05 23:13:13       light rain
# 6        7.81      MX  2021-02-05 23:27:10       few clouds
# 7        8.37      GL  2021-02-05 23:22:53  overcast clouds
# 8        3.44      CA  2021-02-05 23:23:01       few clouds
# 9        8.05      CA  2021-02-05 23:23:18    broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the Weather_Data dataframe into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
